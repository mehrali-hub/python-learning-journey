# %% [markdown]
# # Session 3 :
#  # Author : Mehr Ali
#
#
# # Strings :(Strings are sequence of Characters)
#
# # In Python specifically, strings are a sequence of Unicode Characters
# # difference between ASCII & UNICODE is : ASCII is 8 bit and UNICODE is 16 bit and python characters are UNICODE
# # Creating Strings
# # Accessing Strings
# # Adding Chars to Strings
# # Editing Strings
# # Deleting Strings
# # Operations on Strings
# # String Functions

# %% [markdown]
# # Creating Python strings :
#
# # single inverted commas
# n = 'hello'
#
# # double inverted commas
# z = "hello ali"
#
# #Tripple inverted commas (used for multilines strings)
# s = '''hello zain'''

# %% [markdown]
# # Indexing
#
# # positive indexing :
# # (move from left to right)  e.g in hello it moves from h to o
# # it always start from 0
#
#
# # negative indexing :
# # (move from right to left) e.g in hello it moves from o to h
# # utility of negative indexing : without even knowing the string length we can find the last 2nd last or others string word
# # it always start from -1

# %% [markdown]
# # Positive indexing
# z = 'hello world'
# print (z[0])
# print (z[1])
# print (z[6])

# %%
# Negative indexing 

s = 'hello world'
print (s[-1])
print (s[-2])
print (s[-3])
# Out:
# d
# l
# r

# %% [markdown]
# # Slicing
# # we can extract many strings character together.If we print any specific thig from the string then we can provide the range

# %%
# slicing  if we print any specific thig from the string then we can provide the range 
s = 'hello world'
print (s[0:5])

# step size  if we want in a string but with spcific jum like in hello isf just i want to priint h and HLO then we do a jump of 2 
z = 'hello world'
print (z[0:6:2])
# Out:
# hello
# hlo

# %% [markdown]
# # Reverse the string using a single line of code is :
#
# # print(s[::-1]) <- this code will reverse the wholw string

# %%
s = 'hello'
print(s[::-1])
# Out:
# olleh

# %% [markdown]
# # Edit and Delete the string
#
# # python strings are not changeable when you make a string then it will never be changed , It is totally immutable (it means you cant edit the string)
#
# # If you delete the string use del
# # whole string will be deleted using del but some part of the string is never be deleted as strings of the python are immutable

# %% [markdown]
# # Operations on strings are:
# # Airthematic operator (python string work on  + and *)instead of these two airthematic operator no other operator will work on strings.
# # Relational operator (all relation operators will work on strings)
# # Logical operator
# # Loops on string
# # Membership operator

# %%
# Airthematic operator (+)
print ('sheikh' ' ' + 'ali' ' ' + 'mehr')
# Out:
# sheikh ali mehr

# %%
# Airthematic operator (*)
print ('zain' ' ' * 8)
print ('*&' * 43)
# Out:
# zain zain zain zain zain zain zain zain
# *&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&*&

# %% [markdown]
# # Relational operator:

# %%
'delhi' == 'mumbai'
# Out:
# False

# %%
'delhi' != 'mumbai'
# Out:
# True

# %%
'ali' > 'zain'
# they now compare the ASCII  value of both compared (lexiographically compare on basis pf ASCII value)
# Out:
# False

# %% [markdown]
# # Logical operator:
# # python show a  little weird behaviour regarding a logical operator, If a string is empty python considered its false
# # and operator means if both are true then its true
# # or operator means if one is true then the result is true

# %%
# And operator 
'hello' and 'world' 
# python check that if both are true then in the result of true if he check 2nd string...
# it will directly print the 2nd string
# Out:
# 'world'

# %%
'' and 'hello'
# python consider empty string as false so it directly gave falsy statement
# Out:
# ''

# %%
# or operator 
'helo' or 'world' #if one condition is true then it dont check 2nd one
# Out:
# 'helo'

# %%
'' or 'ali' #1st condition is false so it checks 2nd one
# Out:
# 'ali'

# %% [markdown]
# # common functions that work on all the data types in python is:
# # len
# # max
# # min
# # sorted

# %%
len('hello world') # gave the length of whole string including the spaces
# Out:
# 11

# %%
max('hello world') # print those character from the string that have highest ASCII value among all the string
# Out:
# 'w'

# %%
min('hello world') # print those character from the string that have lowest ASCII value among all the string
# Out:
# ' '

# %%
sorted ('hello world')  # sorting  and its output is list not a string ad its answer is in AScending order on the basis of the ASCII value
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %% [markdown]
# # Functions that only work on strings data type:
#
# # Capitalize/Title/Upper/Lower/Swapcase
# # Capitalize convert the string first letter to capital(used for website)
# # Title convert every sentence first letter to capital letter(use for blogs headings)
# # Upper convert every letter to capital
# # lower convert every letter of a string to lower character
# # Swapcase convert capital letter to lower & lower to capital

# %%
s = 'hello world'
s.capitalize()
# Out:
# 'Hello world'

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s = 'Mehr aLi'
s.swapcase()
# Out:
# 'mEHR AlI'

# %% [markdown]
# # Count/Find/Index
# # count is used to find how many time a letter is present in the string(for frequecy count)
# # Find is used to find index of the element in string
# # Index and find is totally similar

# %% [markdown]
# s = 'my name is ali'
# s.count('i')

# %%
s.find('is')
# Out:
# 8

# %%
s.index('is')
# Out:
# 8

# %% [markdown]
# # endswith/startswith
# # used to check is the string start or end with the particular string or not

# %% [markdown]
# # Format
# # it is used to insert the value of a variable inside the string and order is matter

# %%
name = 'Mehr Ali'
gender = 'male'
age = '20'

s = 'my name is {} and i am a {} and {} years old'
s.format(name,gender,age)
# Out:
# 'my name is Mehr Ali and i am a male and 20 years old'

# %% [markdown]
# # isalnum : check that if given string is alpha numeric or not
# # islapha : check every thing in the string is alphabet or nnot
# # isdigit : check if every hig in the string is digit or not

# %%
s = 'ali123'
s.isalnum()
# Out:
# True

# %%
s = 'ali'
s.isalpha()
# Out:
# True

# %%
s = '12345'
s.isdigit()
# Out:
# True

# %% [markdown]
# # Split : Can break the string word by word and add in the list
# # join : is the reverese of the split

# %%
s = 'my name is ali'
s.split()
# Out:
# ['my', 'name', 'is', 'ali']

# %%
s.split('m')
# Out:
# ['', 'y na', 'e is ali']

# %%
" ".join(['my', 'name', 'is', 'ali'])
# Out:
# 'my name is ali'

# %% [markdown]
# # replace : can replace the particular substring

# %%
s = 'my name is mehr ali '
s.replace('ali','sheikh')
# Out:
# 'my name is mehr sheikh '

# %% [markdown]
# # strip : super useful for software and web development
# # remove the extra spaces

# %%
s = 'ali             '
print (s)
s.strip()
# Out:
# ali
# 'ali'

# %% [markdown]
# # Practise problems in strings :
